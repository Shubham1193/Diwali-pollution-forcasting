# %% [markdown]
# # *** Delhi Air-quality forcasting using ARIMA Model ( PM 2.5 ) ***

# %%
import requests
import pandas as pd
import plotly.express as px
from datetime import date

# %%
key = 'f25b76598ebf3acf7c83ef22c62a541514f6d0ed3ac920f2c50a54b05bd66f31'
res = requests.get("https://api.openaq.org/v2/locations/2178", headers={"X-API-Key": key})
print(res)
# Out:
# <Response [200]>

# %% [markdown]
# ## > Function to fetch data

# %%
import pandas as pd
import requests
from datetime import datetime, timedelta
import time

def generate_date_ranges(start_date, end_date):
    """Generate monthly date ranges between start and end dates"""
    current_date = start_date
    while current_date < end_date:
        next_month = current_date.replace(day=28) + timedelta(days=4)
        month_end = next_month - timedelta(days=next_month.day)
        if month_end > end_date:
            month_end = end_date
            
        yield current_date, month_end
        current_date = month_end + timedelta(days=1)

def query_weather_data(location, start_date="2020-01-01", end_date="2024-09-30"):
    # Convert string dates to datetime objects
    start_dt = datetime.strptime(start_date, "%Y-%m-%d")
    end_dt = datetime.strptime(end_date, "%Y-%m-%d")
    
    all_data = []
    for period_start, period_end in generate_date_ranges(start_dt, end_dt):
        date_from = period_start.strftime("%Y-%m-%dT00:00:00Z")
        date_to = period_end.strftime("%Y-%m-%dT23:59:59Z")
        url = (
            "https://api.openaq.org/v2/measurements"
            f"?date_from={date_from}"
            f"&date_to={date_to}"
            f"&limit=5000&page=1&offset=0"
            f"&sort=desc&parameter_id=2&radius=1000"
            f"&location_id={location}&order_by=datetime"
        )
        headers = {"accept": "application/json", "X-API-Key": key}
        try:
            response = requests.get(url, headers=headers)
            response.raise_for_status()
            converted = response.json()['results']
            month_data = {
                "Date": [],
                "Value": [],
                "location": [],
                "parameter": [],
                "longitude": [],
                "latitude": []
            }
            for entry in converted:
                month_data["Date"].append(entry['date']['utc'])
                month_data["Value"].append(entry['value'])
                month_data["location"].append(entry['locationId'])
                month_data["parameter"].append(entry['parameter'])
                month_data["latitude"].append(entry['coordinates']['latitude'])
                month_data["longitude"].append(entry['coordinates']['longitude'])
            
        
            if month_data["Date"]:  
                df_month = pd.DataFrame.from_dict(month_data)
                all_data.append(df_month)
            
            print(f"Successfully fetched data for {period_start.strftime('%Y-%m')}")
            time.sleep(1)
            
        except Exception as e:
            print(f"Error fetching data for {period_start.strftime('%Y-%m')}: {str(e)}")
            continue
    
    if all_data:
        final_df = pd.concat(all_data, ignore_index=True)
        final_df['Date'] = pd.to_datetime(final_df['Date'])
        final_df = final_df.sort_values('Date')
        final_df = final_df.drop_duplicates()
        print(f"\nTotal records collected: {len(final_df)}")
        print(f"Date range: {final_df['Date'].min()} to {final_df['Date'].max()}")
        return final_df
    else:
        print("No data collected")
        return pd.DataFrame()

# %%
df = query_weather_data(location= 8118)
# Out:
# Successfully fetched data for 2020-01
# Successfully fetched data for 2020-02
# Successfully fetched data for 2020-03
# Successfully fetched data for 2020-04
# Successfully fetched data for 2020-05
# Successfully fetched data for 2020-06
# Successfully fetched data for 2020-07
# Successfully fetched data for 2020-08
# Successfully fetched data for 2020-09
# Successfully fetched data for 2020-10
# Successfully fetched data for 2020-11
# Successfully fetched data for 2020-12
# Successfully fetched data for 2021-01
# Successfully fetched data for 2021-02
# Successfully fetched data for 2021-03
# Successfully fetched data for 2021-04
# Successfully fetched data for 2021-05
# Successfully fetched data for 2021-06
# Successfully fetched data for 2021-07
# Successfully fetched data for 2021-08
# Successfully fetched data for 2021-09
# Successfully fetched data for 2021-10
# Successfully fetched data for 2021-11
# Successfully fetched data for 2021-12
# Successfully fetched data for 2022-01
# Successfully fetched data for 2022-02
# Successfully fetched data for 2022-03
# Successfully fetched data for 2022-04
# Successfully fetched data for 2022-05
# Successfully fetched data for 2022-06
# Successfully fetched data for 2022-07
# Successfully fetched data for 2022-08
# Successfully fetched data for 2022-09
# Successfully fetched data for 2022-10
# Successfully fetched data for 2022-11
# Successfully fetched data for 2022-12
# Successfully fetched data for 2023-01
# Successfully fetched data for 2023-02
# Successfully fetched data for 2023-03
# Successfully fetched data for 2023-04
# Successfully fetched data for 2023-05
# Successfully fetched data for 2023-06
# Successfully fetched data for 2023-07
# Successfully fetched data for 2023-08
# Successfully fetched data for 2023-09
# Successfully fetched data for 2023-10
# Successfully fetched data for 2023-11
# Successfully fetched data for 2023-12
# Successfully fetched data for 2024-01
# Successfully fetched data for 2024-02
# Successfully fetched data for 2024-03
# Successfully fetched data for 2024-04
# Successfully fetched data for 2024-05
# Successfully fetched data for 2024-06
# Successfully fetched data for 2024-07
# Successfully fetched data for 2024-08
# Successfully fetched data for 2024-09
#
# Total records collected: 40027
# Date range: 2020-01-01 00:30:00+00:00 to 2024-09-30 23:30:00+00:00

# %% [markdown]
# ## > Exporting data

# %%
from datetime import datetime
import os

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
filename = f"weather_data_{timestamp}.csv"

try:
    df.to_csv(filename, index=False)
    print(f"Data successfully exported to: {filename}")
    print(f"Number of records exported: {len(df)}") 
    file_size = os.path.getsize(filename) / (1024 * 1024)  
    print(f"File size: {file_size:.2f} MB")
    
except Exception as e:
    print(f"Error exporting data: {str(e)}")
# Out:
# Data successfully exported to: weather_data_20241019_084207.csv
# Number of records exported: 40027
# File size: 2.27 MB

# %%
data = pd.read_csv('weatherdata.csv')

# %%
data.head()
# Out:
#                         Date  Value  location parameter  longitude  latitude
# 0  2020-01-01 00:30:00+00:00  433.0      8118      pm25   77.22445  28.63576
# 1  2020-01-01 01:30:00+00:00  359.0      8118      pm25   77.22445  28.63576
# 2  2020-01-01 02:30:00+00:00  386.0      8118      pm25   77.22445  28.63576
# 3  2020-01-01 03:30:00+00:00  386.0      8118      pm25   77.22445  28.63576
# 4  2020-01-01 04:30:00+00:00  399.0      8118      pm25   77.22445  28.63576

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40027 entries, 0 to 40026
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       40027 non-null  object
#  1   Value      40027 non-null  float64
#  2   location   40027 non-null  int64
#  3   parameter  40027 non-null  object
#  4   longitude  40027 non-null  float64
#  5   latitude   40027 non-null  float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 1.8+ MB

# %%
count_neg999 = (data['Value'] == -999).sum()
print(f"Number of rows with -999: {count_neg999}")
# Out:
# Number of rows with -999: 4117

# %%
df = data[data['Value'] != -999]
print(df.shape)
# Out:
# (35910, 6)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Date'] = df['Date'].dt.date
daily_avg = df.groupby('Date')['Value'].mean().reset_index()
print(daily_avg)
# Out:
#             Date  Daily_Average_Value
# 0     2020-01-01           323.500000
# 1     2020-01-02           254.208333
# 2     2020-01-03           182.208333
# 3     2020-01-04           202.833333
# 4     2020-01-05           155.666667
# ...          ...                  ...
# 1628  2024-09-26            22.727273
# 1629  2024-09-27             6.818182
# 1630  2024-09-28            18.791667
# 1631  2024-09-29            28.125000
# 1632  2024-09-30            59.000000
#
# [1633 rows x 2 columns]
# /tmp/ipykernel_198494/1651407513.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_198494/1651407513.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
from datetime import datetime
import os

filename = f"weather_data.csv"

try:
    daily_avg.to_csv(filename, index=False)
    print(f"Data successfully exported to: {filename}")
    print(f"Number of records exported: {len(df)}")
    file_size = os.path.getsize(filename) / (1024 * 1024)  
    print(f"File size: {file_size:.2f} MB")
    
except Exception as e:
    print(f"Error exporting data: {str(e)}")
# Out:
# Data successfully exported to: weather_data.csv
# Number of records exported: 40027
# File size: 0.04 MB

# %%
finaldata = pd.read_csv('weather_data.csv')

# %%
finaldata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1633 entries, 0 to 1632
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 1633 non-null   object
#  1   Daily_Average_Value  1633 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 25.6+ KB

# %% [markdown]
# ## > Linechart of per hour pm2.5

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(30, 16))
plt.plot( finaldata['Daily_Average_Value'].to_numpy(), marker='o')  
plt.title('Daily Average PM2.5 Values')
plt.xlabel('Date')
plt.ylabel('Daily Average PM2.5 Value')
plt.xticks(rotation=45)
plt.grid()
plt.tight_layout()
plt.show()

# %%
finaldata['Date'] = pd.to_datetime(finaldata['Date'])  

finaldata['Month'] = finaldata['Date'].dt.to_period('M')

monthly_avg = finaldata.groupby('Month')['Daily_Average_Value'].mean().reset_index()

monthly_avg['Month'] = monthly_avg['Month'].dt.to_timestamp()

monthly_avg = monthly_avg.set_index('Month')

monthly_avg.rename(columns={'Daily_Average_Value': 'Monthly_Average_Value'}, inplace=True)

# %%
monthly_avg.head()
# Out:
#             Monthly_Average_Value
# Month
# 2020-01-01             149.677186
# 2020-02-01             118.369383
# 2020-03-01              53.976897
# 2020-04-01              42.850810
# 2020-05-01              49.902506

# %% [markdown]
# ## > PM2.5 value for  Nov Dec Jan

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))

plt.plot(monthly_avg.index.to_numpy(), monthly_avg['Monthly_Average_Value'].to_numpy(), marker='o')

jan_mask = monthly_avg.index.month == 1
nov_mask = monthly_avg.index.month == 11
dec_mask = monthly_avg.index.month == 12

plt.plot(monthly_avg[jan_mask].index.to_numpy(), monthly_avg[jan_mask]['Monthly_Average_Value'].to_numpy(), 
         'bo', markersize=12, label='January')
plt.plot(monthly_avg[nov_mask].index.to_numpy(), monthly_avg[nov_mask]['Monthly_Average_Value'].to_numpy(), 
         'ro', markersize=12, label='November')
plt.plot(monthly_avg[dec_mask].index.to_numpy(), monthly_avg[dec_mask]['Monthly_Average_Value'].to_numpy(), 
         'go', markersize=12, label='December')

plt.title('PM2.5 Monthly Average Values')
plt.xlabel('Month-Year')
plt.ylabel('Monthly Average Value')
plt.grid(False)
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### > we can see the spike  in average PM2.5 for Nov Dec  Jan which indicate that there are effect of diwali and newyear celebration on air quality

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
from random import randrange
from pandas import Series
from matplotlib import pyplot
import matplotlib.pyplot as plt
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## > Seasonal Decomposition

# %%
result = seasonal_decompose(monthly_avg['Monthly_Average_Value'], model='additive', period=12)
result.plot()
pyplot.show()

# %%
result = seasonal_decompose(monthly_avg['Monthly_Average_Value'], model='multiplicative', period=12)
result.plot()
pyplot.show()

# %% [markdown]
# ## > Stationarity Check using Augmented Dickey–Fuller test

# %%
from statsmodels.tsa.stattools import adfuller

def check_stationarity(ts):
    result = adfuller(ts)
    print('ADF Statistic:', result[0])
    print('p-value:', result[1])
    print('Critical Values:')
    for key, value in result[4].items():
        print(f'    {key}: {value}')
    
    if result[1] < 0.05:
        print("Reject the null hypothesis: The series is stationary.")
    else:
        print("Fail to reject the null hypothesis: The series is non-stationary.")

check_stationarity(monthly_avg['Monthly_Average_Value'])
# Out:
# ADF Statistic: -1.2811433618739372
# p-value: 0.6377544918081612
# Critical Values:
#     1%: -3.584828853223594
#     5%: -2.9282991495198907
#     10%: -2.6023438271604937
# Fail to reject the null hypothesis: The series is non-stationary.

# %% [markdown]
# ## > First Differencing to make series Stationary

# %%
differenced_series = monthly_avg['Monthly_Average_Value'].diff().dropna()
check_stationarity(differenced_series)
# Out:
# ADF Statistic: -4.2277179758248735
# p-value: 0.0005912200924020106
# Critical Values:
#     1%: -3.5885733964124715
#     5%: -2.929885661157025
#     10%: -2.6031845661157025
# Reject the null hypothesis: The series is stationary.

# %% [markdown]
# ## > ACF and PACF to check if series if AR or MA or both ARMA and Determining value of p and q

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf


plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plot_acf(monthly_avg['Monthly_Average_Value'], lags=10, ax=plt.gca())
plt.title('ACF Plot')

plt.subplot(1, 2, 2)
plot_pacf(monthly_avg['Monthly_Average_Value'], lags=10, ax=plt.gca())
plt.title('PACF Plot')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## > Fitting ARIMA model with differnent p and q value finding best p q with minimum AIC and BIC values

# %%
import warnings
warnings.filterwarnings('ignore')
from statsmodels.tsa.arima.model import ARIMA
acf_list = [1,5,6,7]
pacf_list = [1,2,3,6,7]

fitted_model_dict = {}

for p in pacf_list:
    for q in acf_list:
        arma_model = ARIMA(monthly_avg['Monthly_Average_Value'], order=(p, 0, q))
        arma_model_fit = arma_model.fit()
            
        aic_score = arma_model_fit.aic
        bic_score = arma_model_fit.bic
    
        fitted_model_dict[(p, q)] = {'AIC': aic_score, 'BIC': bic_score}

# %%
for (p, q), scores in fitted_model_dict.items():
    print(f'ARMA({p},{q}) - AIC: {scores["AIC"]}, BIC: {scores["BIC"]}')
# Out:
# ARMA(1,1) - AIC: 599.8097087153996, BIC: 607.9819137867378
# ARMA(1,5) - AIC: 586.6430901481493, BIC: 602.9875002908258
# ARMA(1,6) - AIC: 586.1110554998002, BIC: 604.4985169103111
# ARMA(1,7) - AIC: 585.1772700812548, BIC: 605.6077827596004
# ARMA(2,1) - AIC: 575.202990267712, BIC: 585.4182466068847
# ARMA(2,5) - AIC: 588.5195517238436, BIC: 606.9070131343545
# ARMA(2,6) - AIC: 569.0995964070254, BIC: 589.5301090853709
# ARMA(2,7) - AIC: 572.849634294098, BIC: 595.3231982402781
# ARMA(3,1) - AIC: 576.8922680115867, BIC: 589.150575618594
# ARMA(3,5) - AIC: 579.6277118802603, BIC: 600.0582245586058
# ARMA(3,6) - AIC: 581.3006301141932, BIC: 603.7741940603732
# ARMA(3,7) - AIC: 575.107681297779, BIC: 599.6242965117935
# ARMA(6,1) - AIC: 569.9115791665598, BIC: 588.2990405770707
# ARMA(6,5) - AIC: 581.0520366023218, BIC: 607.6117030841709
# ARMA(6,6) - AIC: 559.3036131743386, BIC: 587.9063309240223
# ARMA(6,7) - AIC: 562.6181160798117, BIC: 593.2638850973299
# ARMA(7,1) - AIC: 568.5807552390615, BIC: 589.011267917407
# ARMA(7,5) - AIC: 577.8957397637859, BIC: 606.4984575134696
# ARMA(7,6) - AIC: 562.9481207508835, BIC: 593.5938897684017
# ARMA(7,7) - AIC: 562.2488024623318, BIC: 594.9376227476846

# %% [markdown]
# ## > Train Test split

# %%
split_index = int(len(monthly_avg) * 0.9)

train_data = monthly_avg.iloc[:split_index]
test_data = monthly_avg.iloc[split_index:]

print("Training Data:\n", train_data)
print("Testing Data:\n", test_data)
# Out:
# Training Data:
#              Monthly_Average_Value
# Month
# 2020-01-01             149.677186
# 2020-02-01             118.369383
# 2020-03-01              53.976897
# 2020-04-01              42.850810
# 2020-05-01              49.902506
# 2020-06-01              42.563649
# 2020-07-01              30.292512
# 2020-08-01              21.238542
# 2020-09-01              45.354809
# 2020-10-01             124.153385
# 2020-11-01             204.544027
# 2020-12-01             195.691401
# 2021-01-01             211.095138
# 2021-02-01             158.516311
# 2021-03-01              90.524541
# 2021-04-01              73.670092
# 2021-05-01              46.432884
# 2021-06-01              42.934373
# 2021-07-01              34.712588
# 2021-08-01              34.545052
# 2021-09-01              27.710609
# 2021-10-01              73.336206
# 2021-11-01             230.847008
# 2021-12-01             191.311791
# 2022-01-01             165.323749
# 2022-02-01              97.889287
# 2022-03-01              86.118124
# 2022-04-01              98.380709
# 2022-05-01              73.649359
# 2022-06-01              49.172900
# 2022-07-01              27.835766
# 2022-08-01              26.626610
# 2022-09-01              33.730949
# 2022-10-01              91.543420
# 2022-11-01             172.633816
# 2022-12-01             178.389775
# 2023-01-01             199.843908
# 2023-02-01              92.992391
# 2023-03-01              55.715208
# 2023-04-01              63.470000
# 2023-05-01              58.313932
# 2023-06-01              36.084886
# 2023-07-01              27.282082
# 2023-08-01              31.459830
# 2023-09-01              35.295898
# 2023-10-01              92.309003
# 2023-11-01             233.408396
# 2023-12-01             207.410359
# 2024-01-01             242.324302
# 2024-02-01             108.252374
# 2024-03-01              73.818878
# Testing Data:
#              Monthly_Average_Value
# Month
# 2024-04-01              56.780842
# 2024-05-01              83.106266
# 2024-06-01              61.995335
# 2024-07-01              34.348904
# 2024-08-01              19.794569
# 2024-09-01              33.462807

# %% [markdown]
# ## *** Predicted value on Test set ***

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA


model = ARIMA(train_data, order=(6, 0, 6))
fitted_model = model.fit()


predictions = fitted_model.forecast(steps=len(test_data))

plt.figure(figsize=(12, 6))
plt.plot(train_data.index.to_numpy(), train_data.to_numpy(), label='Actual Data', color='green')
plt.plot(test_data.index.to_numpy(), test_data.to_numpy(), label='Actual', color='blue')
plt.plot(test_data.index.to_numpy(), predictions.to_numpy(), label='Predicted', color='red', linestyle='--')
plt.title('ARMA(2, 1) Predictions vs Actual')
plt.xlabel('Date')
plt.ylabel('Daily Average Value')
plt.legend()
plt.show()
print(fitted_model.summary())
# Out:
#                                  SARIMAX Results
# =================================================================================
# Dep. Variable:     Monthly_Average_Value   No. Observations:                   51
# Model:                    ARIMA(6, 0, 6)   Log Likelihood                -238.864
# Date:                   Wed, 23 Oct 2024   AIC                            505.728
# Time:                           10:27:10   BIC                            532.774
# Sample:                       01-01-2020   HQIC                           516.063
#                             - 03-01-2024
# Covariance Type:                     opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         95.4733      6.921     13.794      0.000      81.908     109.039
# ar.L1          1.0089      0.463      2.181      0.029       0.102       1.915
# ar.L2          0.0154      0.917      0.017      0.987      -1.782       1.813
# ar.L3         -1.0307      0.927     -1.112      0.266      -2.847       0.786
# ar.L4          0.0261      0.807      0.032      0.974      -1.556       1.609
# ar.L5          0.9962      0.784      1.270      0.204      -0.541       2.533
# ar.L6         -0.9941      0.411     -2.418      0.016      -1.800      -0.188
# ma.L1         -0.9535      3.278     -0.291      0.771      -7.379       5.472
# ma.L2         -0.0112      4.449     -0.003      0.998      -8.732       8.709
# ma.L3          0.9350      1.793      0.521      0.602      -2.580       4.450
# ma.L4          0.0694      4.646      0.015      0.988      -9.036       9.175
# ma.L5         -0.9356      5.741     -0.163      0.871     -12.188      10.316
# ma.L6          0.9189      3.258      0.282      0.778      -5.466       7.304
# sigma2       645.5929   1877.660      0.344      0.731   -3034.553    4325.739
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.23   Jarque-Bera (JB):                 6.48
# Prob(Q):                              0.63   Prob(JB):                         0.04
# Heteroskedasticity (H):               1.51   Skew:                             0.85
# Prob(H) (two-sided):                  0.41   Kurtosis:                         3.41
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
predictions = fitted_model.forecast(steps=12)
print(predictions)
# Out:
# 2024-04-01     60.134470
# 2024-05-01     56.722106
# 2024-06-01     62.492628
# 2024-07-01     23.112007
# 2024-08-01     20.470869
# 2024-09-01     27.625206
# 2024-10-01     96.115665
# 2024-11-01    176.161320
# 2024-12-01    205.565965
# 2025-01-01    202.580892
# 2025-02-01    129.060914
# 2025-03-01     87.736624
# Freq: MS, Name: predicted_mean, dtype: float64

# %% [markdown]
# ## Arima

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA


future_forcast = fitted_model.forecast(steps=12)

plt.figure(figsize=(12, 6))
plt.plot(monthly_avg.index.to_numpy(), monthly_avg['Monthly_Average_Value'].to_numpy(), label='Training Data', color='green')
plt.plot(future_forcast.index.to_numpy(), future_forcast.to_numpy(), label='Future Forecast', color='red', linestyle='--')

plt.title('ARMA(2, 1) Predictions and Future Forecast')
plt.xlabel('Date')
plt.ylabel('Daily Average Value')
plt.legend()
plt.show()

# %% [markdown]
# ## Sarimax Model

# %%
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX


p, d, q = 6, 0, 6  
P, D, Q, S = 1 ,0 ,1 ,12  

# Fit the SARIMAX model
model = SARIMAX(train_data, 
                order=(p, d, q), 
                seasonal_order=(P, D, Q, S))
fitted_model = model.fit()


forecast_result = fitted_model.get_forecast(steps=12)
future_forecast = forecast_result.predicted_mean
confidence_intervals = forecast_result.conf_int()


future_index = pd.date_range(start=train_data.index[-1] + pd.DateOffset(1), periods=12, freq='M')

# Plot the results
plt.figure(figsize=(12, 6))
plt.plot(train_data.index.to_numpy(), train_data.to_numpy(), label='Training Data', color='green')
# plt.plot(test_data.index.to_numpy(), test_data.to_numpy(), label='Test Data', color='blue')
plt.plot(future_index.to_numpy(), future_forecast.to_numpy(), label='Future Forecast', color='red', linestyle='--')

# Plot confidence intervals
plt.fill_between(future_index, 
                 confidence_intervals.iloc[:, 0], 
                 confidence_intervals.iloc[:, 1], 
                 color='pink', alpha=0.5, label='95% Confidence Interval')

plt.title('SARIMAX Predictions and Future Forecast')
plt.xlabel('Date')
plt.ylabel('Monthly Average Value')
plt.legend()
plt.show()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           15     M =           10
#  This problem is unconstrained.
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.16920D+00    |proj g|=  1.59152D+00
#
# At iterate    5    f=  4.96682D+00    |proj g|=  4.37385D-02
#
# At iterate   10    f=  4.93796D+00    |proj g|=  3.14685D-02
#
# At iterate   15    f=  4.91386D+00    |proj g|=  4.25430D-02
#
# At iterate   20    f=  4.89429D+00    |proj g|=  2.68561D-02
#
# At iterate   25    f=  4.85756D+00    |proj g|=  8.35514D-02
#
# At iterate   30    f=  4.81583D+00    |proj g|=  1.99818D-01
#
# At iterate   35    f=  4.79734D+00    |proj g|=  1.98095D-01
#
# At iterate   40    f=  4.78200D+00    |proj g|=  1.60612D-01
#
# At iterate   45    f=  4.75015D+00    |proj g|=  1.90423D-01
#
# At iterate   50    f=  4.73485D+00    |proj g|=  4.48874D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    15     50     66      1     0     0   4.489D-02   4.735D+00
#   F =   4.7348470178752011
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT

# %%
test_data
predictions = future_forcast.head(6)

# %%
print(fitted_model.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                Monthly_Average_Value   No. Observations:                   51
# Model:             SARIMAX(6, 0, 6)x(1, 0, [1], 12)   Log Likelihood                -241.477
# Date:                              Wed, 23 Oct 2024   AIC                            512.954
# Time:                                      10:27:30   BIC                            541.932
# Sample:                                  01-01-2020   HQIC                           524.028
#                                        - 03-01-2024
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9682      0.857      1.130      0.259      -0.712       2.648
# ar.L2          0.5532      1.604      0.345      0.730      -2.591       3.698
# ar.L3         -0.3311      1.174     -0.282      0.778      -2.631       1.969
# ar.L4         -0.4256      1.048     -0.406      0.685      -2.480       1.629
# ar.L5         -0.5111      1.312     -0.390      0.697      -3.083       2.060
# ar.L6          0.7397      0.725      1.021      0.307      -0.680       2.160
# ma.L1         -0.5511      5.375     -0.103      0.918     -11.085       9.983
# ma.L2         -0.8774      0.778     -1.127      0.260      -2.403       0.648
# ma.L3         -0.0201     12.774     -0.002      0.999     -25.057      25.017
# ma.L4          0.8983      4.999      0.180      0.857      -8.900      10.697
# ma.L5          0.5509      6.700      0.082      0.934     -12.582      13.684
# ma.L6         -0.9497      5.000     -0.190      0.849     -10.750       8.851
# ar.S.L12       0.9564      0.114      8.389      0.000       0.733       1.180
# ma.S.L12      -0.4901      0.442     -1.108      0.268      -1.357       0.377
# sigma2       430.3413   2171.144      0.198      0.843   -3825.022    4685.705
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.08   Jarque-Bera (JB):                 0.16
# Prob(Q):                              0.78   Prob(JB):                         0.92
# Heteroskedasticity (H):               1.35   Skew:                            -0.02
# Prob(H) (two-sided):                  0.54   Kurtosis:                         3.27
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ### The SARIMAX model fitted to the monthly average air pollution data incorporates six non-seasonal autoregressive terms (AR), no differencing, and six non-seasonal moving average terms (MA), alongside one seasonal autoregressive term and one seasonal moving average term with a seasonal period of 12 months. The model demonstrates a strong fit, indicated by a Log Likelihood of -241.477, an AIC of 512.954, and a BIC of 541.932. Key coefficients reveal that the first lag of the AR component is highly significant (p < 0.05), while the seasonal AR term is also significant, highlighting its importance in capturing annual patterns. However, most non-seasonal MA terms are not significant, suggesting potential simplification of the model. Diagnostic tests, including the Ljung-Box test for autocorrelation and the Jarque-Bera test for normality, indicate that the residuals do not exhibit significant autocorrelation and are normally distributed, affirming the model's adequacy. Overall, the SARIMAX model effectively captures the underlying structure of the data, making it a robust tool for forecasting future values.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import seaborn as sns


mse = mean_squared_error(test_data, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(test_data, predictions)
mape = np.mean(np.abs((test_data - predictions) / test_data)) * 100
r2 = r2_score(test_data, predictions)


print("Model Performance Metrics:")
print(f"R-squared (R²): {r2:.4f}")
print(f"Mean Absolute Error (MAE): {mae:.4f}")
print(f"Root Mean Square Error (RMSE): {rmse:.4f}")
# Out:
# Model Performance Metrics:
# R-squared (R²): 0.6782
# Mean Absolute Error (MAE): 7.9976
# Root Mean Square Error (RMSE): 12.0307

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
scaler.fit(train_data)
# Out:
# MinMaxScaler()

# %%
pip install keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras in /home/shubham/.local/lib/python3.10/site-packages (3.6.0)
# Requirement already satisfied: ml-dtypes in /home/shubham/.local/lib/python3.10/site-packages (from keras) (0.4.1)
# Requirement already satisfied: packaging in /home/shubham/.local/lib/python3.10/site-packages (from keras) (24.1)
# Requirement already satisfied: rich in /home/shubham/.local/lib/python3.10/site-packages (from keras) (13.9.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras) (1.26.4)
# Requirement already satisfied: absl-py in /home/shubham/.local/lib/python3.10/site-packages (from keras) (2.1.0)
# Requirement already satisfied: h5py in /home/shubham/.local/lib/python3.10/site-packages (from keras) (3.12.1)
# Requirement already satisfied: optree in /home/shubham/.local/lib/python3.10/site-packages (from keras) (0.13.0)
# Requirement already satisfied: namex in /home/shubham/.local/lib/python3.10/site-packages (from keras) (0.0.8)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/shubham/.local/lib/python3.10/site-packages (from optree->keras) (4.11.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/shubham/.local/lib/python3.10/site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/shubham/.local/lib/python3.10/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /home/shubham/.local/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
scaled_train = scaler.transform(train_data)
scaled_test = scaler.transform(test_data)

# %%
import tensorflow as tf
n_input = 12
n_features = 1
generator = tf.keras.preprocessing.sequence.TimeseriesGenerator(scaled_train , scaled_train , length = n_input , batch_size = 1)

# %%
from tensorflow import keras

# %%
X , y = generator[0]
print(X)
print(y)
print(X.shape)
# Out:
# [[[0.58094489]
#   [0.43933558]
#   [0.14807989]
#   [0.09775514]
#   [0.12965088]
#   [0.09645627]
#   [0.0409523 ]
#   [0.        ]
#   [0.10908105]
#   [0.46549739]
#   [0.82911484]
#   [0.78907325]]]
# [[0.85874638]]
# (1, 12, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
model = Sequential()
model.add(LSTM(100 , activation = 'relu' , input_shape=(n_input , n_features)))
model.add(Dense(1))
model.compile(optimizer = 'adam' , loss = 'mse')

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                   │ (None, 100)            │        40,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,901 (159.77 KB)
#  Trainable params: 40,901 (159.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(generator , epochs = 50)
# Out:
# Epoch 1/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1288
# Epoch 2/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1002
# Epoch 3/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0885
# Epoch 4/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0867
# Epoch 5/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0888
# Epoch 6/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0563
# Epoch 7/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0423
# Epoch 8/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0283
# Epoch 9/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0321
# Epoch 10/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0316
# Epoch 11/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0512
# Epoch 12/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0258
# Epoch 13/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0436
# Epoch 14/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209
# Epoch 15/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0175
# Epoch 16/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0392
# Epoch 17/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0268
# Epoch 18/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0207
# Epoch 19/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0189
# Epoch 20/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0108
# Epoch 21/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0383
# Epoch 22/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0341
# Epoch 23/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0226
# Epoch 24/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0226
# Epoch 25/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0226
# Epoch 26/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0174
# Epoch 27/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165
# Epoch 28/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0276
# Epoch 29/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0214
# Epoch 30/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209
# Epoch 31/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0209
# Epoch 32/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0163
# Epoch 33/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0191
# Epoch 34/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0181
# Epoch 35/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0196
# Epoch 36/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0124
# Epoch 37/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0136
# Epoch 38/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0151
# Epoch 39/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0231
# Epoch 40/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0099
# Epoch 41/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0144
# Epoch 42/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0120
# Epoch 43/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0184
# Epoch 44/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0126
# Epoch 45/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0196
# Epoch 46/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0207
# Epoch 47/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0153
# Epoch 48/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0178
# Epoch 49/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0114
# Epoch 50/50
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0114

# %%
loss_per_epocs = model.history.history['loss']
plt.plot(range(len(loss_per_epocs)) , loss_per_epocs)

# %%
last_train_batch = scaled_train[-12 : ]

# %%
last_train_batch = last_train_batch.reshape(1 , n_input , n_features)
last_train_batch
# Out:
# array([[[0.19101845],
#         [0.16769687],
#         [0.06715197],
#         [0.02733573],
#         [0.04623223],
#         [0.06358327],
#         [0.32146105],
#         [0.95967218],
#         [0.84207964],
#         [1.        ],
#         [0.39357502],
#         [0.23782778]]])

# %%
model.predict(last_train_batch)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# array([[0.19465151]], dtype=float32)

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1 , n_input , n_features))

for i in range(len(test_data)):
    current_pred = model.predict(current_batch)[0]
    test_predictions.append(current_pred)
    current_batch =  np.append(current_batch[: , 1 : , :] ,[[current_pred]] , axis = 1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step

# %%
test_predictions
# Out:
# [array([0.19465151], dtype=float32),
#  array([0.13276538], dtype=float32),
#  array([0.08299693], dtype=float32),
#  array([0.0582369], dtype=float32),
#  array([0.06000925], dtype=float32),
#  array([0.10010258], dtype=float32)]

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
test_data['predictions'] = true_predictions

# %%
test_data.head()
# Out:
#             Monthly_Average_Value  predictions
# Month
# 2024-04-01              56.780842    64.273220
# 2024-05-01              83.106266    50.591078
# 2024-06-01              61.995335    39.587981
# 2024-07-01              34.348904    34.113892
# 2024-08-01              19.794569    34.505732

# %%
test_data.plot(figsize=(12 , 6))
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse =sqrt(mean_squared_error(test_data['Monthly_Average_Value'] , test_data['predictions']))
print(rmse)
# Out:
# 17.935461685832657

# %% [markdown]
# Forecasting

# %%
forecastedvalue = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1 , n_input , n_features))

for i in range(13):
    current_pred = model.predict(current_batch)[0]
    forecastedvalue.append(current_pred)
    current_batch =  np.append(current_batch[: , 1 : , :] ,[[current_pred]] , axis = 1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step

# %%
forecastedvalue = scaler.inverse_transform(forecastedvalue)
forecasted_series = pd.Series(forecastedvalue.flatten(), index=pd.date_range(start='2024-04-01', periods=13, freq='M'))
print(forecasted_series)
# Out:
# 2024-04-30     64.273220
# 2024-05-31     50.591078
# 2024-06-30     39.587981
# 2024-07-31     34.113892
# 2024-08-31     34.505732
# 2024-09-30     43.369797
# 2024-10-31    142.187816
# 2024-11-30    242.170267
# 2024-12-31    246.614051
# 2025-01-31    208.862981
# 2025-02-28    109.835065
# 2025-03-31     76.381917
# 2025-04-30     56.467710
# Freq: ME, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'forecasted_series' contains your forecasted values
forecasted_series = pd.Series({
    '2024-04-30': 64.273220,
    '2024-05-31': 50.591078,
    '2024-06-30': 39.587981,
    '2024-07-31': 34.113892,
    '2024-08-31': 34.505732,
    '2024-09-30': 43.369797,
    '2024-10-31': 142.187816,
    '2024-11-30': 242.170267,
    '2024-12-31': 246.614051,
    '2025-01-31': 208.862981,
    '2025-02-28': 109.835065,
    '2025-03-31': 76.381917,
    '2025-04-30': 56.467710
})

# Convert to a DataFrame for easier manipulation
forecast_df = forecasted_series.reset_index()
forecast_df.columns = ['Month', 'Predictions']

# Convert the Month column to datetime and set it to the first day of the month
forecast_df['Month'] = pd.to_datetime(forecast_df['Month']) + pd.offsets.MonthBegin(0)

# Set the Month column as the index
forecast_df.set_index('Month', inplace=True)

# Now you can print the adjusted forecast DataFrame
print(forecast_df)

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(train_data.index.to_numpy(), train_data.to_numpy(), label='Training Data', color='green')
plt.plot(forecast_df.index.to_numpy(), forecast_df['Predictions'].to_numpy(), label='Forecasted Values', color='blue', marker='o')


plt.title('Forecasted Values Starting from 1st of Each Month')
plt.xlabel('Date')
plt.ylabel('Forecasted Value')
plt.xticks(rotation=45)
plt.legend()
plt.grid()
plt.show()
# Out:
#             Predictions
# Month
# 2024-05-01    64.273220
# 2024-06-01    50.591078
# 2024-07-01    39.587981
# 2024-08-01    34.113892
# 2024-09-01    34.505732
# 2024-10-01    43.369797
# 2024-11-01   142.187816
# 2024-12-01   242.170267
# 2025-01-01   246.614051
# 2025-02-01   208.862981
# 2025-03-01   109.835065
# 2025-04-01    76.381917
# 2025-05-01    56.467710
